# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# In Natural Language Processing, Sentiment Analysis refers to methods that systematically extract, classify and predict the polarity (positive or negative) of text documents. Let's implement a **Support Vector Machine** that learns from a dataset of ~100k positive and negative observations.

# %%
import numpy as np
import pandas as pd

import re
from nltk.corpus import stopwords

# %% [markdown]
# # Load data into a pandas dataframe

# %%
data = pd.read_csv('sentiment.csv', encoding='latin1')

# %% [markdown]
# ## Let's check out the first 5 rows

# %%
data.head()
# Out:
#    ItemID  Sentiment                                      SentimentText
# 0       1          0                       is so sad for my APL frie...
# 1       2          0                     I missed the New Moon trail...
# 2       3          1                            omg its already 7:30 :O
# 3       4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4       5          0           i think mi bf is cheating on me!!!   ...

# %% [markdown]
# ## Print the number of unique labels and the length of the dataset

# %%
print(len(data.Sentiment.unique()))
print(len(data))
# Out:
# 2
# 99989

# %%
print(data.groupby('Sentiment').size())
# Out:
# Sentiment
# 0    43532
# 1    56457
# dtype: int64

# %% [markdown]
# **0 shows us the number of negative tweets and 1 shows us the labels for positive tweets.** We have quite a bit more positive than negative examples. Imbalanced data can be a problem sometimes, especially when you deal with small datasets and multi-class classification. There are many ways how to deal with imbalanced classes, e.g. collecting more data, upsampling, data augmentation, re-balancing with weights, etc. In this case with have close to 100.000 observations and binary classification, let's move on for now and see how it goes.

# %% [markdown]
# # Pre-processing

# %% [markdown]
# Get the label and text columns of our dataframe and transform them to arrays

# %%
labels = data.Sentiment.values
text = data.SentimentText.values

# %%
labels
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
text
# Out:
# array(['                     is so sad for my APL friend.............',
#        '                   I missed the New Moon trailer...',
#        '              omg its already 7:30 :O', ...,
#        '@CuPcAkE_2120 ya i thought so ',
#        "@Cupcake_Dollie Yes. Yes. I'm glad you had more fun with me. ",
#        '@cupcake_kayla haha yes you do '], dtype=object)

# %% [markdown]
# Looking at the text, it's very messy. Even at a first glance we see a lot of problems, like multiple whitespaces (makes it difficult for our tokenizer), a lot of usernames, urls, etc. We need to clean up the text before we feed it to our machine learning model. We want to reduce the amount of noise as much as possible, ease up the process for the tokenizer, reduce the number of features, e.g. by removing stopwords (very high in frequency, but don't contain any meaning).

# %% [markdown]
# ### (a rough) Clean up

# %%
texts = []

for i in range(0, len(text)):
    tweet = re.sub('@([A-Za-z0-9_]+)', ' ', text[i]) # replace usernames with a whitespace
    tweet = re.sub('http([:/A-Za-z0-9_.]+)', ' ', tweet) # replace urls with a whitespace
    tweet = re.sub('www([:/A-Za-z0-9_.]+)', ' ', tweet) # replace urls with a whitespace
    tweet = re.sub('[^a-zA-Z0-9.:_!?\-\(\)]', ' ', tweet) # replace everything that is not in the selection with a whitespac
    tweet = re.sub('(\s+)', ' ', tweet).lower().split() # replace multiple whitespaces with one whitespace, lowercase everything
    tweet = [word for word in tweet if not word in set(stopwords.words('english'))] # remove stopwords
    tweet = ' '.join(tweet)
    texts.append(tweet)

# %%
texts
# Out:
# ['sad apl friend.............',
#  'missed new moon trailer...',
#  'omg already 7:30 :o',
#  '.. omgaga. im sooo im gunna cry. dentist since 11.. suposed 2 get crown put (30mins)...',
#  'think mi bf cheating me!!! t_t',
#  'worry much?',
#  'juuuuuuuuuuuuuuuuussssst chillin!!',
#  'sunny work tomorrow :- tv tonight',
#  'handed uniform today . miss already',
#  'hmmmm.... wonder number -)',
#  'must think positive..',
#  'thanks haters face day! 112-102',
#  'weekend sucked far',
#  'jb isnt showing australia more!',
#  'ok thats win.',
#  'lt -------- way feel right now...',
#  'awhhe man.... completely useless rt now. funny twitter.',
#  'feeling strangely fine. gonna go listen semisonic celebrate',
#  'huge roll thunder now...so scary!!!!',
#  'cut beard off. growing well year. gonna start over. happy meantime.',
#  'sad iran.',
#  'wompppp wompp',
#  'one see cause one else following pretty awesome',
#  'lt ---sad level 3. writing massive blog tweet myspace comp shut down. lost lays fetal position',
#  '... headed hospitol : pull golf tourny 3rd place!!!!!!!!!!! think re-ripped something !!! yeah !!',
#  'boring ): whats wrong him?? please tell me........ :-',
#  'bothered. wish could spend rest life sat going gigs. seriously.',
#  'feeeling like shit right now. really want sleep nooo 3 hours dancing art assignment finish.',
#  'goodbye exams hello alcohol tonight',
#  'realize deep. geez give girl warning atleast!',
#  'hate athlete appears tear acl live television.',
#  'miss guys think wearing skinny jeans cute sweater heels really sure today',
#  '-- meet meat',
#  'horsie moving saturday morning.',
#  'sat off...need work 6 days week',
#  'really dont like room boring sick wardrobe cant waiit till walk one yay',
#  'sox! floyd great relievers need scolding!',
#  'times like million',
#  'uploading pictures friendster',
#  'type spaz downloads virus? brother : msn fucked forever : (',
#  'amp amp fightiin wiit babes...',
#  '(: !!!!!! - wrote something last week. got call someone new york office...',
#  'enough said',
#  '... need even say it? i? well go anyways: chris cornell chicago! ... tonight!',
#  '... health class (what joke!)',
#  'lt 3 go show tonight',
#  'really makes sad look muslims reality',
#  '- time low shall motivation rest week.',
#  'entertainment someone complained properly.. experimental say? experiment melody',
#  'another year lakers .. neither magic fun ...',
#  'baddest day eveer.',
#  'bathroom clean..... enjoyable tasks......',
#  'boom boom pow',
#  'proud.',
#  'congrats helio though',
#  'david must hospitalized five days end july (palatine tonsils). probably never see katie concert.',
#  'friends leaving cause stupid love',
#  'go give ur mom hug right now.',
#  'going see harry sunday happiness',
#  'hand quilting then...',
#  'hate u ... leysh t9ar5 ... ((((((( ..',
#  '- always get want',
#  'bend backwards',
#  'get work sooooon! miss cody booo. seen foreverr!',
#  'hate allergies. get hair cut tomorrow? taking public poll...',
#  '- love guys much hurts.',
#  'miss earl',
#  'miss new jersey',
#  'missed first hour sytycd last night find online!',
#  'need u2 fix now!',
#  'never thought become second choice...',
#  'think may friendly...lol... well...',
#  'think manuel (my basil plant) days live',
#  'wanna home church...i wonder wht doing?',
#  'wanna make pizza',
#  'want 120gb harddrive 37 inch tv new guitar. anyonefeeling generous? p x',
#  'want hug',
#  'want miley tour australia',
#  'wanted sleep morning mean kid popsicle stick head. wish could fly away like squirrels',
#  'slow get 1 tix',
#  'send sunshine northern ireland going swimming today',
#  'wish could go t4 beach : ( would great see amp',
#  'would much happier walls bedroom painted white',
#  'idk wat 2 trust im sorry 4 da pain caused nebody ima take dis time 2 straighten luv yall',
#  'finding intercept slope..and banging head wall..math brain heads come save',
#  'really going bed now...',
#  'im sick cough cough',
#  'cab headed airport! going home.... lt christy gt',
#  'case feel emo camp (feeling wee bit alr)...am bringing human rights watch world report 2009..hope work',
#  'jin twitter.',
#  'jonas day almost over...',
#  'jus got hom fr. tda funeral... sad! cried much times! much love grandpa! lt 3 never got say last quot goodbye quot him.',
#  'gonna smile...cuz is..and im sure could want..',
#  'got home got see friend zahra seen since graduated!!! makes happy.',
#  '- longest night ever.. ugh!',
#  'mi momacita let go bf bball game!!! grrr!!!',
#  'mom says get new phone immediately....off t-mobile. paying....',
#  'new car stolen....by mother wanted go pose church.',
#  'hang girls 2day. 2moro hope so......',
#  'movie times sunday! rats plan tomorrow. guess means work two presentations doing!',
#  'pavel tonight lt tigersfan gt',
#  'cool night.',
#  'oh thank you!',
#  'pleased',
#  'probably guna get soon since one talkin',
#  'really wanted safina pull win amp lose like that...',
#  'rip david eddings.',
#  'rose ood back xmas special! yay! damn half year away.',
#  '- sannesias: aww neighbor! need watch mean girls :',
#  'whats status next weekend',
#  'sorry ex husband overdosed daily dose haterade',
#  'thanks definition throwbie! editors reviewed entry decided publish it.',
#  'thanks need help get.',
#  '- explains alot.',
#  'going heathers sequel. winona4ever! better fuck up.',
#  'told drink w rx gave b.b. porter amp obs. stout brought home neighbors. v v sad.',
#  'trae sweet! bought new baithing suit!! wove',
#  'true highly subjective there. tombre actually favorite character book. got - - rishabh',
#  'u guys knw whyy',
#  'much',
#  'waahhh getting sad....miss hub :- ( quot quot quot quot quot quot quot quot',
#  '-- standing pouring rain.. sitting top world.. -- summer sucks --',
#  'went get dog vets theyve stitched ear charged us still bleeds like waterfall everytime moves. d: why!',
#  'picture feel naked',
#  'trains going manchester sunday?!! go concert.',
#  '- must people picky. mean 6 hours work dice!? that!',
#  'twitter soon become obsolete?',
#  'wide awake not!!!',
#  'yeah too. awful weather last week stinks. kristis comin moe said mmmaybe take us ...',
#  '- you: hi stranger: hello frank lampard you: fine you: urself stranger: gay your...',
#  'always one only... 12 23 2007',
#  '3turnoffwords shit sucks',
#  'asylm j2 panel over. guess back normal life.',
#  'poemsunder140 ....started',
#  'squarespace brighten bad day! never win anything...',
#  'susan boyle didnt win! mh well diversity good though! congratz!!',
#  'twenty20',
#  'lt --- believe me.. enough!',
#  'lt 3 goooood timessss',
#  'lt 3 graduate 09 lt 3',
#  'quot vandals paint swastikas home author gay lesbian church story : naples daily news quot ( )',
#  'quot unknown error occured (-4) quot . uh oh. iphone os 3 fail far',
#  'quot experts (homers) predict eagles go 12-4 giants go 9-7 bs! ?t 49343',
#  'quot know hungry lets go outside balcony eat quot ....',
#  'quot want bad driving mad quot',
#  'quot 10 men uk female internet entrepreneur know starting growing business : next women quot ( ...',
#  'quot truth hiding eyes quot paramore decode ? 5ytke',
#  'quot try turn tv get head. got feeling inside admit... quot (that literally feel)',
#  'quot well truth miss quot - coldplay',
#  '(tears) : -( today last day kids...they go summer break dads tomorrow. sighs',
#  '(unsure) (annoyed)',
#  '(via ) designed gallery exhibition postcards mailers going extinct? via nyt',
#  'beautifulylost',
#  '- cries going miss harry potter comes out. leaving vietnam july 11th. going cry!!',
#  '-- hummin say quot shut amp put money mouth quot ...headin reality. cheers twitter world!',
#  '-- . sigh cant love someone love back like stalker status . get divorce amp amp move . trinity.',
#  '. . . . going back bed lookin around see reason awake atm. little.',
#  '-- . aiqht goodniqht . tri neena malcolm chaise jlew atl lt 333 love much .',
#  '-- . triiiiiii . ily . even chaise . dies laughter',
#  '.. wantt hiim soo badd !!',
#  '.. watching tv bed shopping w. mom w. trent hopefully need best friend',
#  '... weird encounters many homeless creeps walk home tonight awesome... really...',
#  '... rained truck race',
#  '... feeling worse??? f!!!',
#  '.... feeling pain happiness time. confusing!',
#  '..... hot choco best!',
#  '....in shirt panties. celulite',
#  '..had turn back north due body line. missing design council design 4 tech transfer event',
#  '..y everything hard? :',
#  '.bueno good bye. good night',
#  ': beach day scoobs. ( : still phone.',
#  ': let fun . give ya give ya.',
#  ': want move!!!',
#  ':-d ))))))))...what amazing night day amp night again!! hi twits! miss u guys',
#  'canaveral national seashore',
#  'progressing production department quot uprizing quot thats priority getting head nodding beats reach',
#  'taylorrhicks enjoy chicago..b new venue always cool. shine everywhere go. know are. time everyone.',
#  'train crash dc .....',
#  'thestreetforce',
#  'makes smile.',
#  'first day 3 weeks child got 7:00. watch quot nancy grac..',
#  ': quot video woody woodpecker barber seville great wishing ch... 7g6r0',
#  'happy staying around here. drexel fabulous university. proud. yeah.',
#  'happened angels demons lions tigers bears!?',
#  'well sure minimizes impact...lol',
#  'call dibs voltron arm. leg. wait. manners? ..',
#  'saw ur mum',
#  'get fat asses here. nai.',
#  '- see three external monitors one laptop win7rc 1 x 1920x1080 2 x 1280x1024',
#  'quot facebook.com copic.marker cool. cool. maybe send cool ..',
#  'want start morning later new york (californians even better)',
#  'lol luv it! gt gt any1 find c 1? a..',
#  'making fettucini garlic bread!',
#  'tell said happy bday!!',
#  '- went work last year pants. ironically last day work job. fml',
#  'told would sweep haha :-p',
#  '. r many gr8 science cartoons',
#  '- edinburgh fringe 10 weeks away?! need monies btw elliott - blame twitter intrusion',
#  'didnt come school?? done short stack thing still need me?',
#  '- one? - latter us store iphone comics',
#  'magic ..thinking less 50 chance hedo stays orlando. gonna go . do. blame though.',
#  '..now wud make beautiful plc cry?',
#  ': outer fat kid.',
#  '- servers backup experience problems please let know sorry delay...',
#  ': quot yes lol j k luv this! : quot like gentle breeze blown throug... 7s7mn',
#  'se morrea mi joseph se vale.',
#  'future rooooooooomies! nyc holler',
#  'hope u cheese burgers 4 lmbo',
#  'awesome',
#  'nothing kind everything sort',
#  '- quot ..pick flowers teacher.. quot jealous! want flowers without hospital get them!',
#  '- think talvez seja nfase na cifra. mas aten o: quot security chain strong weakest link',
#  'youtube account suspended? lol single ladies dance? need watch again!',
#  '- know.. sold though.',
#  '- - watch e3 -',
#  '- thanks k! hoping! pretty nervous though...',
#  'get aim talk me. miss her.',
#  '?????????????????????????????????? ????????????1000 followers????????????',
#  'tell ya grocery store. better blasted oldies. sugar ray make me..',
#  'kashrut convo makes want keep kosher roomies catholic amp pork loin fridge kosherfail',
#  'home neither ... u better it!!!',
#  'yall bitches better wake early go la opera kay!?',
#  '- - immune dentists drills etc bother all. gum lift surgery next week tho eek',
#  'r u tonite im still awake!',
#  'hates bebot app',
#  'quot congrats bhai like oldies gt used say - arre bhai kuch kam ka',
#  '',
#  'chilling twitter via spanking new blackberry w unlimited internet :',
#  'give every inch love every night?',
#  '',
#  'maybe pop tweet. quite active twitter.',
#  'shame women mamma mia horny since men island so..',
#  '- thanks letting know. going check eureka later knowledge',
#  'u referring to?',
#  '',
#  '- up? hey you! ok thx. you? too! ttyl! oh sowwy! lol',
#  'happy mothers day!',
#  '- knew sharepoint written interns knew !!',
#  'miss much already...',
#  'practising.....how feel',
#  'miss love jamie',
#  'fuck you!',
#  'head feels like bowling ball',
#  'heart hurts badly...',
#  'fs keeps crashing try load bungie plane.',
#  'current headset deathbed now! dad gave 3 weeks back!',
#  '.... mood currently blah . sitting parking lot',
#  'happy',
#  '...that all.',
#  'everyone went home. everyone even here! cmf lt 3',
#  'fed up....',
#  'fuck fuck fuuuuck!',
#  'feeling today make matters worst super nasty rainy outside yuck!',
#  '',
#  'wanted aiden davis 2 win lt 3 bummed didnt',
#  'bed time now....',
#  'faltam 4 dias para world drawing day',
#  'friends like ... thanks fake!',
#  'haha omg. stayin steezy amp mowin lawn... loviie still amp amp goiing tanning soon.',
#  'think bf cheating me!!!!',
#  'wanna play camera settle playing iv heart monitors',
#  'want octo drive',
#  'want display pretty voltron! upside get two pretty voltrons!',
#  'want find way put photos phone bluetooth phone computer work',
#  'effort bring best content added lease 30 hours release digital rapture. soon... hang tight',
#  '--- response happened today. all.',
#  'j right... hurts.',
#  'kinda really kinda',
#  'let moment silence childhood homes... sadly replaced never go back',
#  'lol robotpickuplines hilarious',
#  'man oh man (i punch head im ok that)',
#  'friends get ur friends b friends shit could every weeknd.. aiigght? coop n crew',
#  'man worth tears one make cry!',
#  'rain rain go away!',
#  'storms scary!',
#  'beautiful satisfying day bargain shopping. loves it.',
#  'tell girls clocking lol',
#  'thank god today friday !!! love ti ti! lt 3',
#  'batt internet connection died. guess back mobile!',
#  'thrilled work morning',
#  'break dance hearts short stack ringtone.... love song!!!.....',
#  '18th',
#  'squarespace trackle apple iphone card us maybe tomorrow! guess helps tweet huh? forgot',
#  '(unsure) (hassle) (: (music)',
#  'exhausted',
#  'want ben amp jerrys cake batter please ugh',
#  'life lazzzzyyyy!!!!!!!',
#  'wish ella somebody',
#  'ish good mood .....tlk',
#  'think going go 3 long drive get pacific ocean open car door throw pc ocean',
#  'hell bbc?',
#  'canucks',
#  'dont like weekend.. huhuhu ( (',
#  'get right away!',
#  '- j made nice..... twice!',
#  'loves life atm! brilliant xd',
#  'else happy mood??',
#  '!bye everyone!',
#  '...lonely night',
#  'blue work',
#  'geez feeling pain',
#  'miss summertime daley.',
#  'computer ... . . . . . . ill lol fuckin goin portugal',
#  'far good!',
#  'today great day!!!',
#  'ughhhhhhhhhhhhhhhhhhhhhhhhhhhhh',
#  'battleground',
#  'lot lot lot lot lot lot lot lot lot lot lot lot.',
#  'wanted aiden davis 2 win lt 3 bummed didnt',
#  'curtain drops crown uptown 32 ye',
#  'eh must leave new mexico soon!',
#  'fail maths knew slow',
#  'gongwer oh report sounds like leadership still considering library cuts considering tax increases. saveohiolibraries',
#  'fuck sake. things never work me?',
#  '- going town toda cousinnn netball match cancelledd',
#  'hoping see baby girl',
#  'even know.',
#  'lost member family',
#  'sick bedtime battles',
#  'cold morning...... chills over.....',
#  'just...',
#  'no. tonight goes books worst sytycd results show.',
#  'shopping',
#  '- poor lil mousey enjoying sunny day. think feel bad big gnarly rat though. dbl standard? yep.',
#  '-- epic sad face.',
#  'magazine story broke heart dentist office today:',
#  'tiger woods 2at 18 via',
#  'wanna go meet wifey t.... sux : (',
#  'wondering feel like do...i feel better though...its good! happy inspite of...tweet ya lata',
#  'yippeeeee yay lets gather hay...his love found way boy gonna stay added 2 master holy way: way',
#  'iranelection - one realizes deep goes.',
#  'gt . bodies air france crash found (via )',
#  'lt story life whole bunch frownies!',
#  'noooooooooo friends twitter makes sad someone follow',
#  'want hear you. guess asking much..',
#  'hardest working chica know( mii boss lady) (look seriously) lol',
#  'really2 like condition. sucksssssss',
#  'orlando lost series. oh well maybe phoenix boston cleveland (the teams like) make next year!',
#  'rinitis sucks!!!!!',
#  'thanks bestttttttttttttttttttt j-dawg',
#  'gt ( gt ( mad sad right now. played terrible today soccer basketball.',
#  'lt - mustache man desperate',
#  'lt --------- face missing zoro tonight.',
#  'know huh im bout cry thanks marco! muah',
#  'angry',
#  'praise god beautiful day!!!',
#  'sry matt 2 hear (',
#  'fucccckkkkkkkkkk',
#  'bye world!!!!!!',
#  'couldnt even one fairytale night',
#  'working pottercast lupins willows come near me. fail.',
#  'cell phone screen dead. sooooooooooo texts know calling. fuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuck',
#  'sickness. strike say strike! ohhhh well nother day school guess',
#  'nobody likes year one reviews read. disappointed. maybe like since expecting much..',
#  '(must say more?)',
#  'old dead gone',
#  '... go ??? 13 minutes ... please please please',
#  '!! love guyssss! rings.. mmmyeahh! bling blingg',
#  '(chance) boo 29',
#  'thank much dvd suggestion! nice you! looks good.',
#  'really hate this.',
#  'bad day.',
#  'bad day.....damn . kind ticket sale that.....',
#  'boston globe could shut 60 days',
#  'bye guys!!!! miss ya sooo sooo much! worry back monday!!! awesome weekend!!! peace!!!!',
#  'followers : ( ... sad... losing hope -pressure',
#  'bless da mic w bra music 2day',
#  'cry cry cry',
#  'f kn day...',
#  'goodnight',
#  'grandma sick. well. going emergency room.',
#  'wonderful day g_d grrrrrrrrreat!!!!!',
#  'going shed tears cavs go home tonight. like seriously',
#  'soooo sad...at point night cuddling jonathan like 4 years',
#  'hate forever.',
#  'passed 70-542 exam today',
#  'missed',
#  'still feel like douchebag',
#  'want write song. think will.',
#  '- always thought time estimates use value pi rule (x 3.14). exception pi squared rule .',
#  'creativity via twitter',
#  '- tease wanna hear tracks!!',
#  'never answering im',
#  '15 traveltips 4 student safety roughplaces',
#  'fathers day picked me...yet. kind want incessantly bother you... squarespace',
#  '... fml',
#  ': quot gotta love blip.fm - john mayer trio - california dreamin heard conan 06 04 2009 ---... 7qdf0',
#  'case need help w that:',
#  'im sure love lol',
#  'quot karl lagerfeld quot twitter profile(s) lol! heart first pic',
#  'longer cab. say heartbroken understatement... good luck everything! amazing ian.',
#  'broke twitter..',
#  'clubbing... must come sheffield sometime amp party really probably atm. tech conference conf etc',
#  'avatar figure people either.',
#  'fulfilling life ambition 2 go 2 jonas brothers concert went 2 hmv new album already sold out! me?',
#  'happened movies anyway? like hollywood forgot: rough times public wants see..',
#  'yelled picking apple store food.',
#  ': quot whoops credit due gt gt gt rb : quot ? 7d4pk',
#  'gt exit cessna 206 skydiving',
#  '1 cats kittens died 3 days old too..rip ming.',
#  '1 week palm pre comes centro dies. temp phone contacts transfered yet. sadpanda fb',
#  '- 20 chicken mcnuggets 2 double cheeseburgers large fries lemonade dinner. may ask? hate body.',
#  '3 hrs da phone...lol dude hilarious',
#  '- 400th tweet (!) breakfast: everything bagel toasted w cream cheese iced cap... delish',
#  '5 gb video upload utube :o dam sony vegas making big',
#  '50 new footwear labeling norm definitions never referred document. wrote up?',
#  'big angry spider crawling blankeys flicked floor cant sleep',
#  'blessed sunday everyone!',
#  '- couple years sickness piled one day',
#  'dog riding bicycle',
#  'fly landed green chile stew. never big killing bugs asshole asked it. goes appetite',
#  'problem shared buck passed',
#  'a_ got handshake meeting. vibe sucks',
#  '? hitech',
#  '(jonah:whats tweet!?) sharon!!!!!!!!!!!!',
#  'alice beating scooby doo board game!',
#  'quite tired wait till wwe burswood lt 3',
#  'anyone advice cope break up?',
#  'arrrrrrrgggggggghhhhhhhh!!!!!!!!!! lines communications temporarily suspended!',
#  '- awake ready day',
#  'nasty studio woman!!! go sleepies!!!',
#  'understand.',
#  'cars inspected today gonna cost 600 dollars',
#  'e out!',
#  'everythings wrong.',
#  'exercise 2 build muscle mass thing speeds metabolism:',
#  'feeling ok first time days. thank you!',
#  'found new way text yey!',
#  'friends dying horrible.',
#  'going paddle 2moz',
#  'good nite. hope grandma visits dreams tonight. last night uplifting... miss her.',
#  'goodbassplayer... funny.... ) oilipo.... hope people bring us good things started early week...',
#  'best there.',
#  'hungover........ craving chocolate! omg funny pub last night!! lol',
#  'dont want sister leave whole summer!',
#  'hope everyone church go concert peace wed. dont worry rushing back church visit',
#  '- spilt last jordans cereal floor distraught',
#  'miss family friends.',
#  'see missed nectar sucking dirty talk )',
#  'want freaking puppy now! cute little black yorkshire terrier.',
#  '- want irissa back',
#  'glad diversity got through...but stavros!',
#  'tell ya ... yummy. decided go hunt blender drinks ... know good ones?',
#  'nutella',
#  'rlly tht serious? abt go thru fonebook...',
#  'listenin new fav band amor',
#  'environmental studies driving mental',
#  'always seen bits amp pieces shottas. seen whole movie...it ends sooooo sad gonna cry.',
#  'another day paradise. )',
#  'found bone chicken nugget cool',
#  '- like said back still fucking hurts going complain like one business....',
#  'love you! lt 333',
#  'aunties dog getting put hes dogs brother aswell',
#  '- head feels like going explode - mmm horrendous image... mess!',
#  'head killing meee',
#  '- name amy. three eyes swollen cannot see must stupid must bad what...',
#  '- picture kris karmada gone forever comments mysapce my...',
#  'confirmed: missing air france flight 447 crashed atlantic :',
#  '1 4 myspace comments gone. cause someone hacked onto wills account. kept abusing others delete it.',
#  'school....... soon wait celebrate stres till',
#  '- pop movie amp chill bit... get innnnn.! call n text',
#  '- swim',
#  'abt missing air france plane. follow best air news source:',
#  'afi reading til sunday sucks !!!!!!!!!',
#  'crap night looking forward cheered no. never mind.',
#  'ah postman package. goon rest day.....',
#  'ahh school monday!!!! ready',
#  'ahhh. drizzy. mr. rogers indeed best.',
#  'airport express rock enough allow wireless scanning canon pixma mx310 otherwise wireless goodness.',
#  'alistair friends kitchen pjs...i want cup tea dammit!',
#  'day.. play.',
#  'dressed bicyclist monday nite ride n henderson ky',
#  'want arms want arms',
#  'friends gone haley n katie camp paris moms landin n ayonna aunts n moms im bored',
#  'nighter. yeeeeeeeeeeeessshhhh nightmare coming 2 weeks. cannot wait graduate!',
#  'small things...',
#  'non-robsten posts making sad. mean knew see others words. sad.',
#  'allison didnt win. have.',
#  'almost time leave.',
#  'already getting sleepy...i really want get psych quizzes done tonight...',
#  '- always nice thing wake to. yay. :p (gosh typical lame overanalyzing teenager) lmao nice nap.',
#  'excited',
#  'feelin happy!?',
#  'feeding pig ?',
#  'losing mind cause wanna see my.tc tv right min? fu2 want 2see candygirls!! daisy -dammit!!',
#  'sad say get results today somehow school forgot mail results me?? typical. ugh',
#  '-- alarm clock device waking people small children. ---',
#  'mend broken heart? 8k7kl',
#  'think felt really sick depressed school today cuz stress.. glad got chest :',
#  'starting get confident myself! torn down!',
#  'anoron.reedcourty.operaunite.com webserver content home.sch alternat va',
#  'another 45 mins....',
#  'another early day',
#  'another father day weekend get spend dad..',
#  'another friday night rock band',
#  'anticipating tough day ahead',
#  'anyone know ghostbusters region free 360?? get us copy britain',
#  ': million making difference. help believe. came believing amp leave believing god is!',
#  '- ?ove lt 33',
#  '6:30...what wrong wit it?',
#  '- alergic... nose itchy eyes burning... hope getting better soon....',
#  'keep coming! xox',
#  'another expensive weekend trip vet.',
#  'parties tonight!? im hella bored home seems like everyone busy!! lammmmeee',
#  'chilli prawns make pain better...',
#  'daughter beloved diabetic dwarf hamster died hands morning...all creatures worthy love.',
#  'dd pinkeye...not fun.',
#  '-- farrah fawcett dies cancer 62 - abc news (via )',
#  'feeling hopeless useless.',
#  'forgot lunch home',
#  'general motors sold hummer :s :s',
#  'good morning all! great day!!!',
#  'goodnight..',
#  'gooood night!! must prepare tomorrows meeting',
#  '- great! im bored moment idea do! missing boyfie too! damn m...',
#  'luvly day',
#  'hot !',
#  'hmm do!',
#  'five guys locations closed visit lt em gt inside edition lt em gt rat patrol',
#  'actually crying sore throat.',
#  '- feel irresponsible sort horrible. marshmallows unless otherwise stated gelatin. fuck...',
#  'miss brother.. worry him.',
#  'need think something else first.',
#  'wanted julian win!',
#  '- iowa no. 2 happy! yea!',
#  'jus got bad news',
#  'got home',
#  'mean',
#  'saw sink whole video kerrang! ive seen loads much better tv!',
#  '- limp bizkit - rollin songstuckinmyheadwheniwokeup',
#  'love save empty',
#  'camera broke !',
#  'mom funniest person ever!',
#  'parents left',
#  'nadal french open ... back-up -- go andy roddick!',
#  'ass beatings checked playhouse baltimore weekend well. feeling quite rested bit sorts.',
#  'nothing....',
#  'ok talk boyfriends stuff tomorrow ) lmao talk real soon too!! wooo hehe ilysfm doodle xxxx',
#  'pie seems quite good appetite now.',
#  '- server problems - motivating change hosting providers though... fb',
#  'shakes head',
#  'shock loss sparks...bummer great game shock many injuries start season...rematch monday!',
#  'asshole got hold email signed spam mail. ughhhh...it non stop. anyone spam blocker?',
#  'someone said ast least pretty . thanks pretty gets nowhere much integrity .',
#  'myspace people get really angry answer right away... ja!',
#  'never get photo comments space',
#  'nhl: penguins 1 red wings 3 - final - red wings lead series 1-0 - stats stars visit',
#  'tickets germany miley cyrus tour..',
#  'photo shoot rained out... oh well back post!',
#  'r.i.p young teke!!! miss cuzin!! lt 3 1 year sence died. . . dont ashamed faith',
#  'rip charles j ...the world one less fine fellow',
#  'rsl paley talk?! even depressed get ticket. oh wells.',
#  '- amazing -- bjork bachelorette ? 4lfyi',
#  'bored',
#  'much good weekend',
#  'thank you.',
#  'hotel know either... favorite! poopie that.',
#  '- thelovelybones: plan owning judge me.',
#  'year 5 million children hunger-related causes.',
#  '- ticketsandpassports: lmao nerd. think cool guys like anime.',
#  'mothers whose day may happy. god loves you. tlc - waterfalls ? 5zi9g',
#  'today good day. guess laying around house undies bad.',
#  'went maggie bday party came home without phone... feel lost reaallly confused (but thats booze talking)',
#  'rb2 get australian release date???',
#  '!my grandma told thinks stupid. well hey thanks g.',
#  'andyhurleyday',
#  'asot400',
#  'betseyjohnson me? necklace 150 rather usual 50-60 want',
#  'followfriday',
#  'imisscath imisscath imisscath imisscath imisscath imisscath imisscath imisscath imisscath imisscath imisscath imisscath',
#  'mcflyforgermany mcflyforgermany mcflyforgermany mcflyforgermany mcflyforgermany mcflyforgermany mcflyforgermany mcflyforgermany',
#  'p1wimax signal detected gardens',
#  'trackle',
#  '-- gt then. ( -- gt now.',
#  'lt 3 pic u want tell cause got',
#  'lt ---my expression watching again:',
#  'quot beach ball fail quot - ?v7-20659 lol fail',
#  'quot freelance writer braille porn stunt double hand model palmolive dishwashing liquid. quot',
#  'quot im love care knows ! quot -elf',
#  'quot raining quot (c) supertramp',
#  'quot must people insist talking stupid politics comments bubblegum pop song. sorry get quot',
#  'quot alone quot',
#  'apparently new 3.0 build gm meaning likely minute issues gm. mlia',
#  'archie annoying morning says hogged bed night get shower little black kettle self',
#  'ok ?',
#  'argh speakers macbook screwing slowly dying.',
#  '-as simple gets.',
#  'chris brown . . . honestly dont feel bad rihanna anyways . . . nd . . .',
#  'last night',
#  'tweets: 1 lady saying goodnite 2 tweets later 1 lady saying good morning - crazy - would never imagined yrs ago',
#  'nursery. wailing ended. sleeping soundly. working morning shift tmrw. grr',
#  'random mention core 2 quot deals quot almost twice much sense tied tv every night.',
#  'work ! fuck !',
#  'work got loads b4 leave today. toodles lufflies xxx',
#  'attempting get people twitter(other cate) talk failing',
#  'aw. toy story 3 coming next year.',
#  'awake...finally..random dream...i penguin lived jersey oddly lived icecream store lolz',
#  'awesome',
#  'awesome black coffee... anyone?',
#  'aww great song quot picture burn quot',
#  'aww gota homework',
#  'aww someone borrowed without telling me.',
#  'awww derek work back making kandie little ones :o',
#  'b- genetics 2.75 towards gpa. really sucks got 79.75 class 80 b.',
#  'baby died last night. day.',
#  'baby girl upset.....i need sewing... almost 10pm finally eating little dinner..sigh..',
#  'baby sitting today.. shopping tomorrow.. rue 21 best ever..',
#  'baby like favorite dessert get enough love 4eva',
#  '- back cali missing itttttt',
#  '- back pain',
#  'back basics',
#  'bad day 2day. broken glasses rainy weather uof',
#  'bad night pens',
#  'bad timing- new mommy called newborn pictures fit baby schedule matter hard try',
#  'bahahaha jodie burst kevin sos dance! epiccc xd',
#  'bank account negative 118...',
#  'bas one last time 2 update status',
#  'baseball.',
#  'bcd closed! guess nodaji is.',
#  '- bed gotta get early 5 days bullshit . summer!!! lt 3',
#  'bed time......................................................',
#  'bedss gayyyy ... oh well goodnight people',
#  '- 2 days straight. lol. never sleep.',
#  'afraid food eating disorder right?',
#  'told im beautiful doesnt make tummy better',
#  'besides great graduation day. finaly made highschool graduate ! moms word .. chapter close .. keep pushing foward.',
#  'still phone. bukas pa raw afternoon... oh well survived 7 days one more... day... another day another destiny',
#  'nice day',
#  'summertime dj jazzy jeff fresh prince',
#  'iphone commission while.',
#  'weather lushhh!',
#  'things good head. may around lot weekend.',
#  'third date went well....moving fourth!!!!!!',
#  'death! awesome random comic certifiably sane. ( )',
#  'try enjoy ur family amp need anything-anything!!!. love sis-be brave amp know u r strong ur prayers',
#  'twilight !!!',
#  'twitter wont let send replies today - boo hoo',
#  'two days.',
#  'ughhh..',
#  'uva baseball... come boys',
#  'water works gonna start',
#  '- well wrote missive post last night things happened got deleted tho by...',
#  'well guess knew going break sometime...',
#  '- canadians proud',
#  'raining?',
#  'me?',
#  'xd go day!!!',
#  '- yay star testing week! start school 11am week school thursday! maybe sf...',
#  '- hello world! live: beautiful 5am woop - bed',
#  'shortstack tokiohotel shortstack tokiohotel shortstack tokiohotel shortstack tokiohotel shortstack tokiohotel shortstack',
#  'squaresp squarespac squarespace trackle giveaways giveway iphonegiveway squarespace squarespce trackle',
#  'lt free! gt',
#  'lt ----that smiling.',
#  '- quot ......you asleep gathered things dark. burns fingers left spark... quot -',
#  'quot bbc news uk maps climate change forecasts quot - picture paints alarming one ( )',
#  'quot giving you. care mess life now. quot ... : (',
#  'quot meteorologists predict chilly rainy midsummer news finland yle.fi quot thunder ( )',
#  'quot nintendo dsi portable game system - do? quot ( )',
#  'quot promote site - getting front page places social media quot ( )',
#  'quot universe living conscious old. cares lots ways. quot drunvalo melchizedek.',
#  '- quot world makes music people listen quot',
#  'quot digg new share feature pollute twitter? quot ( )',
#  '(angry) mixed motions! soo frustrated x(',
#  '(mood in)',
#  'exited bought oreos!! hope everyone likes oreos..',
#  'hugs',
#  'sends e-hugs',
#  'tear',
#  'cries depressed thanks angel! quot gonna find someone someday might actually treat well quot !!',
#  '--- way doctors duo ass even breakfast yet lol',
#  'sob must bed!!',
#  'wishes summer jam',
#  'school! grrr im mood take make back put teachers leave!',
#  '-- . babbbbbbbbyy . missed much!!',
#  '. sunday over.',
#  '-- . well gon stop w. . quot idc quot shit. faithful like points em moi!',
#  '.. jonas bad us !! come paraguay',
#  '... jonas day!!!!!!!!',
#  '... ughh... anybody wanna come house cook? mom leavin work aint cook shit !... trust dem hoes!!!',
#  '.... know do..',
#  '.... think lost spanish book!! :-x',
#  '.... life complicated. know god plan .... trust him.',
#  '......... oh well least suzumiya haruhi yuuutsu air.',
#  '.........not really good night guys ! buu huu',
#  '...i get cast keep looking dance opportunities. need exercise.',
#  '...the ground around wet... looked see drops fall face...it drizzle around missing drops',
#  '..i forgot bring new sharpie pens school today..booo!',
#  '..omg...my celly off...this happened years...wtf!!! gota get bill paid',
#  ': last gadget geek_and_poke',
#  ': ( horrible',
#  ': ( ius one person make smile',
#  ':s tweetdeck killing hate',
#  ') july flowers (july 2009) holiday',
#  'last.fm working.',
#  'finally got twitter haha',
#  '',
#  'think may connection paul reubens reason movie theater fl..',
#  '- - saw earlier even comprehend couple feeling. really tragic',
#  '- - temperature pain still bad. hoping antibiotics kick soon! thanks asking',
#  '-- said tweets less days hi!',
#  'would love see guys sometime! grin - aw rats maybe warm real fast??? lol',
#  '- hope actually birthday getting shots.',
#  'signature 100 rubbed mondayeyes bracelet. least plenty autographs still. sad day.',
#  'quot quot ? 7d1qo',
#  'happened gone? anybody get arrested',
#  '- know u find replacement 4me. still pay u not. let u hang',
#  'seeing guy dressed banana totally made day. phallic symbol ftw',
#  '- yep coz england game wednesday',
#  'alllllan ruins lifeeee.',
#  '-- . boo. blushes',
#  '-- . byyeee . ily2 jamarcusssssss',
#  '. want buy sims 3 . sold . wtf . haha..',
#  '-- . aint gotta apologize. know ugly.',
#  '..',
#  '.. yep things way time. selfish. everything revolves around me. yep. im bitch. great (y)',
#  '... ...i wanna get rid twitter guys cool...',
#  '... try... try hard... seem get credit it.... wats prob?',
#  '- ... wide awake dont actually wanna go school :s xxx',
#  '.... dream beautiful.',
#  '.... one roommate....',
#  '..... im givin 5 minutes turn frown upside',
#  '......i cant even say word right',
#  '.....why sad??...becuz u becuz exam??.....i think..becuz u...',
#  '...? ..frustrated?',
#  '...and feel shallow breath squeezes past fifty pounds stone laid chest.',
#  '...just found friend childhood passed away... may rest peace.',
#  '...still office...',
#  '...that',
#  '..sniffles... since dont get leave fucking house...aw great power gone. getting dark.. puurfect!',
#  'feel ... ... left',
#  '::sigh:: didnt win contest . stupid popularity contest. many votes also. im realy sad. good feeling',
#  '( noooo! why? things complicated spelt wrong idc',
#  '( noooo! why? things complicated spelt thy wrong idc',
#  ') butterfly day (jun 19 2009) holiday',
#  '??? means ?',
#  'jfk international airport',
#  'jonas brothers youtube bein suspended',
#  'moval court 4 traffic ticket..i b sleeping..aahh.',
#  '- work.. 5 hours today weeeekend! wait long weekend begin! gonna get things done sure!',
#  'praying cold go head skunk sprayed yard. w..',
#  'created realms light pure love commands fold think speak love new world behold',
#  'music quiet sure massive hoax played. alone. i..',
#  'sold frozen bananas today!',
#  'car come either.',
#  'disappeared',
#  '- oi tell daughter lower ticket prices cant afford london sister cried.',
#  '- lol. quot cat. quot huge fan. also think think hold sims 3',
#  'speaking historian wtf incorporate twitter buzz upper middle class north ame..',
#  ': farrah fawcett star quot charlie angels quot died cancer 62.',
#  '- yes show suggested ought celebrity deathmatch',
#  'dear hyper chihuahua 45 minutes left together drive ..',
#  'washington capitals would one myweakness well.',
#  'looking fwd twitpic selma soon. cool name add k end tok ra',
#  '',
#  'yea really wanna see win daytona',
#  'great follow',
#  'aww sorry bae u kno grindin got u swear....i needa go buy artbook construction paper',
#  '- hey you! long on? thx! hehehe yw ) yeah not!',
#  ': quot : quot nobody told violent femmes covered gnarls barkley! quot tks dude!! quot ? 6svjq',
#  'unfortunately coming nj boonies...i gotta drive path',
#  '- gigs weekend cancelled may temporary shut good. still trying find out. boo.',
#  'started working warm fluffy fart ? tweet realizing especially like far..',
#  'news google getting twitterpated? -',
#  'mad me. fail',
#  'lol nooooooooo!!!',
#  'played ur joint two songs ago. everyone studio feeling it!',
#  '- get excited conan.',
#  'thanx post amp warm wishes.. enjoy ur day!',
#  'youu welcomee',
#  'thru miracle modern science bruce danny child...',
#  'stopped talking me. stalk her.',
#  '- - pleased know nice night sleep even comfy bed ) even sleeping bag would',
#  'try sex bing deactivate safe search go video. porn site without lea..',
#  'toolio court 24th...',
#  'meet tonight please tell story. laker fans made miss show!',
#  '902 thanks!',
#  '- hope get better soon',
#  'saw...',
#  'slept late too. wonder u did...mhmm. hype u think leave country 2 weeks amp 3 days.',
#  'one???',
#  'ahhhhhh - bloody five. give away house (and sky subscription)?',
#  'upset lol',
#  'well praise lord 4 gud moods kno need 2 b 1 im workn thighs amp dark clouds scaring',
#  'sending tweets wrong account although selected right one.',
#  'aw sweet leslie tweeting luv last night! 1 absolute fave!',
#  'big ass kool-aid smile face talkin boo...',
#  'bleh... feel like qqing now.',
#  'blowdrying hair',
#  'boo',
#  'bored........doing nothing all....okay...i pretty shy girl...',
#  'boredddd going powerpoint',
#  'boring nite...damn guess better get use',
#  'boro let down. getting tight.',
#  'bosco graduation sara voice recital',
#  'breakfast family',
#  'britains got talent right ! good luck susan boyle )',
#  'bummed missing bb kris comcast chat. stupid responsibilities.',
#  'burnt tongue hot chocolate downside',
#  'eatting popcorn getting better',
#  'want boyfriend summer.',
#  'love aaron.',
#  'him! brown nose telling super-duper beautyful said day before: sorry someone died!',
#  '- suddenly something happens write portuguese',
#  'first see mtv movie awards thursday!! sad!! lt 3 lt 3 looking forward thursday!! jubii!!',
#  'join you? _ karenwild',
#  'canon powershot s400 served well. sorry left u car hottest 3 days... mourn loss',
#  'cant afford see angels demons watched free:',
#  'get motivated might b sunday crying club me!!',
#  'cant get auckland watch jb 3d movie. im soo gutterd. suppose wait till dvd release..',
#  'log computer work. ack! got lots do. guru today. anyone help me?',
#  'make labels til computer fixed..can fix computer make money..can make money unless sell soap grrrr',
#  'sleep -_- sucks eggs bacon! suppose get early',
#  'sleep damn miserable! sooooo itchy please help sleep going cry! : (',
#  'wait hills finale tonight!',
#  'wait weekend bmth saturday!',
#  'carrie bad eye infection...just waiting hear vets see found anything',
#  'cba revising french oral fuck',
#  '- certification test 2 8:30 morning. feeling much better one today',
#  'changin name ambergirl66 ) haha youtube name mathces background )',
#  '-- chilling niggahz haley dylan',
#  'chocolate cake delicious strawberry yummy yummy',
#  'church matt was...good. think going churchgirl now. )',
#  '-- city tonight mae!',
#  'cnt even use single twitter app!!!!!',
#  'cold despite heater. weirdly though actually cold today!',
#  'come bitchesss barakatday barakatday barakatday barakatday',
#  'come party',
#  'come manchester england id love meet fun germany? beautiful love it. (l) xx',
#  'coming home stretch j fic. yay!!',
#  'computer tempermental moment....',
#  'congrats al newest state senator elect democrat mark keahey. alpolitics',
#  'content. quot made pac lets see long last quot',
#  'cookies first time',
#  'could night worse?',
#  'find',
#  'cramps. drugs--good.',
#  'crap day tat get craper',
#  'credit card bill. ow wallet.',
#  '-- dad came back amp asked us go anyer till thu! gonna go back amp forth banten anyer us. poor',
#  'dads got turn power caio',
#  'dammit... sleep me.. day to.. :-',
#  'damn gettin someone right damn guess im sleeping tonite texts..',
#  'damn u still sleep? look up...i think royalty beats city council',
#  'damn! didnt make time border closed! drove hr. toher side state make ti mexico!.sniff! sniff! tired!',
#  'damn lost three followers... getting close fifty.. help out?',
#  'damn. something wrong. youu',
#  'dan birthday.',
#  'darn city want leave!',
#  'def. studio ur jus gunna get lyrics shrug',
#  'definately bedtime',
#  'definately missed train. smh. fuck!',
#  'depressing day ? 6tfp6',
#  'devstateddd silly iphone deleted jailbreak stuff thats 25 apps !',
#  'get go see up!! oh well ended going dinner blase bridget!',
#  'get much sleep cos flippin neighbours! grr time work again!',
#  'get car scheming tonight. sad. get mosh looking like complete bogan woots!',
#  'go last night fell asleep .... suck (not literally)',
#  'time updating 2 busy enjoying quot love making sleep clothes amp eating bbq quot weather. miss lt 3',
#  'think netball coz raining got ... one take manee going b annoyed :',
#  'win twitter contest. boo',
#  'dinara lost roland garros. safins hard?',
#  'dinner lt bath lt workout lt run',
#  'diplomatic husband wife quot u expect remember ur birthday u never look older? quot (via )',
#  'dissapointed.',
#  'anybody know statistics homework started nobody answering emails business studies...',
#  'know get fir tattoo',
#  'dont feel good ptosis )',
#  'forget vote today!',
#  '- ignore smell sizzling skin sitting sun!',
#  'dont know whats wrong',
#  'like ending night arguing huz smf stupid home improvement crap.',
#  'wanna go work',
#  'tweetwrath think coined new word twitter dictionary',
#  '- guys fun last night? hope got text... pub quizzage tomorrow?',
#  '',
#  'know miss someone bitch brussels trams metro bad customer service lack quorn.. etc.',
#  'class answer work road n nola im hungry no1 2 eat with!',
#  'funny fact: 3x town population following tumblr. h..',
#  'gonna miss too. really gonna 2-3 years might end visiting aussie land (i wish)',
#  '- guess end love affair emusic.',
#  '',
#  '- taking lunch today',
#  '',
#  'busy see london evening. boy do?',
#  'never twitter anymore',
#  ': lmao',
#  'twitter maintenance friday night? really listening think wo..',
#  '.exe (do-er) .ppt (talk-er) .txt (leafy potted plant)',
#  'trent reznor quits twitter - (via )',
#  '- would love meet made plans already get another opportunity soon!',
#  'lovely compliment. thx much!',
#  'thankyou',
#  'update: sb 110 fwy x 8th st correction: dead female 16 lafd complete chp amp coroner handle nfd - brian humphrey',
#  'kstew still together happy not?? lol im happy kristen happy',
#  '- oh no! good link!',
#  '- - front black would got white one. black looks sleek amp white',
#  '- - full voice control making want iphone 3gs 02 charge fortune 3g contract til april',
#  'dat. jst tell em 2 suck ur dyck! always makes feel better',
#  '- awesome 4th quarter ladies! great game',
#  'messing mind.',
#  'quite opposite',
#  '- night thanks call',
#  'makes wanna cry',
#  'know difference! like say long time. long time',
#  'thank you. genuinely grateful',
#  '- pretty much look like candy floss machine today',
#  'posterous looks like tumblr iphone? looks interesting. fold content ..',
#  'dont wanna leave ny today.',
#  'dont worry amigos!! still hangin lt 3',
#  '3k chips.',
#  'downloaded one movie yesterday problem thnk deserve that...',
#  'driving lizzie airport. say good bye lizzie.',
#  '-- dt tonight dt tomorrow day amp night beauty.',
#  'dude almost shocked myself. lesson learned never get outta shower think electricity hate ur ass.',
#  '- eaten steak!!! im feeling good! much better!! missing lady though',
#  'eating last wizz fizz',
#  'ecl day try cram organic chemistry back head. final tomorrow. ugh',
#  'eff bitch dunkin donuts',
#  'elise melanie shiz',
#  'ellie text saying quot theyre gona read text they? quot speak mcfly!',
#  'emotional.',
#  'everton f.c. got beat finals f.a. cup chealea f.c. oh well least got finals played well!',
#  'everton. oh well. lol.',
#  'every fucking day',
#  'every one talking msn gone offline able talk till tomorrow feel lonely : ( x',
#  '- every often catch reflection amp think .. one cool son-of-a-b tch .. today one days',
#  'every time leave room miss bubu sending msg gone side.its hapnin day...universe?!!mxit',
#  'everyones drunk',
#  'everyones dying bordeirlne svu',
#  'exams.....help !',
#  'expensive car repairs',
#  'explore twitter',
#  'f amp ing red wings!',
#  'failed inspection. know pass wo oven wo anti-tip bracket sold w oven? worse taxes.',
#  'failing everything give now....',
#  'famed michigan bookstore close doors',
#  'famliy going bck homee take sister hores riding oh gonna boring day',
#  'farrah fawcett dies cancer 62.',
#  'fcukk you!',
#  'fedex kicked french open ...',
#  'feelin pessimistic ):',
#  'feeling litle sad',
#  'feeling sad leaving mumbai...',
#  'feeling down. reality setting in. know beyond point. still here? want follow dreams im scared',
#  'feels bad cali... poor thing.',
#  'female model tortured prince',
#  'ferrets much cooler fishes.',
#  'field trip today leaving :3',
#  '- finally home bout napp get ready college tomorrow ughhh sooo excited !',
#  'finally managed check euromillions results......no 89 million afraid : oh well...you gotta win it!',
#  'finding hollywood video frequent re-model-ing fact closed cancels account much 4 super cheap dvds',
#  'hope fun quot lisa quot jillian replacement lol... busy getting drunk! lol lt 3 u both... xo',
#  'missed all..imma call u tomorrow..and reduce number qs tomorrow pls...i phobia lol seriously',
#  'followfriday ppl catch crabs',
#  'light bit punch. mission san francisco gin mexican liqueur seemed apt name.',
#  'super emo stupid stuff rn sg making feel better. :p',
#  'bullpen loses lead',
#  'amp anyone else said something too.',
#  'mean best religion thing follow right way',
#  'bows raid. quot dunn quot back inn. speedy recovery mate.',
#  'yeahuhh',
#  'worse day ever. boss spazzing work finally done late night photo shoot flat',
#  'called cheeseburglar. made sad',
#  'didnt win first award nominated for. oh well.. shes tied nominations.',
#  'says quot crush commies quot sad. grandfather rip commie',
#  '- well none us getting alive would like stay while.i wish people would stop killing',
#  'boston 2day boo!! roll summer already!!! x',
#  'sorry...got carried away gossip another note: pass hippo birdie amp big koala hug kris me! xoxo k',
#  'office. know hard believe people want employ me.',
#  ': lmao lt 3',
#  'hi ur back amp ur next mk gona need 1 really good hugs friend liam give ok.',
#  'lost groups thats good thing 23k followers',
#  'guardian uk: 12 students reported killed crackdown violent clashes iran',
#  'badly one know got far',
#  'said flickr mac install os x (yes): quot user-focused design goes exploding colostomy bag quot',
#  '__cheer emo kid.',
#  'lvatt comming!!!',
#  'next days',
#  'happy sunday',
#  '1 dinger regret popping pill...',
#  '1 month bed 1:30am already failing see',
#  '2 days tlkd 2 mi amor..im kinda stubborn comes 2 bf..i call..not bugaboo type',
#  '2 hear jon n kate...couples steer clear reality shows! say no!',
#  '--- 2009 ncaa national softball champions uw huskies',
#  '2nd item arrive still waiting show aramex web page.',
#  'finished paper!!!!!!!!!! but............ smh',
#  'first days always good..wish dentist gave hours though',
#  'fone off....cant talk 2 love....imu marcus!!!!!',
#  'fact get work done did.',
#  'forgot xbl today check see game xbla wanted buy oh well maybe tomorrow',
#  'found mosquito bite. (those tend get really swollen red me) distracting caffeine',
#  'found way make private woot woot',
#  'four fake people added me. people like twitter?',
#  'frank iero sexiest vegetarian 2009.',
#  'french lost fb',
#  'fuck man .i hate this. o. work suckss : (',
#  'fuck :',
#  '- fuck money running amp jobs...',
#  'fuck. ugly person.',
#  'fucking rur mom',
#  ...]

# %% [markdown]
# ## X (documents) and y (labels). We're predicting ŷ.

# %%
X = texts
y = labels

# %% [markdown]
# ### First things first. We are using the scikit-learn Countvectorizer to assign an integer to each token

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000) # choose the max number of features carefully
X = cv.fit_transform(X).toarray()

# %% [markdown]
# ### Let's count the occurrences and show a list of the top 20 tokens in our dataset

# %%
occ = np.asarray(X.sum(axis=0)).ravel().tolist()
counts_df = pd.DataFrame({'term': cv.get_feature_names(), 'occurrences': occ})
counts_df.sort_values(by='occurrences', ascending=False).head(20)
# Out:
#       occurrences    term
# 3497         9153    quot
# 1894         5923    good
# 2576         5538    like
# 2626         5400     lol
# 1846         5310     get
# 2468         4609    know
# 2657         4515    love
# 4355         4116  thanks
# 3108         3744     one
# 1881         3641      go
# 1184         3493     day
# 3785         3260     see
# 242          3177     amp
# 4776         3174    well
# 4425         3084    time
# 4970         3073     you
# 1908         3027     got
# 2328         3000      it
# 3088         2955      oh
# 4380         2886   think

# %% [markdown]
# Okay. We see some positive sentiment-bearing words that are very high in frequency. Another important hint is 'quot'. From just skimming through the first few rows of our dataset we couldn't see it, but we have a lot of HTML tags and those should be removed in the pre-processing phase, or even better, prevent it to happen in the first place. For now let's move on and see how the performance will be when we skip that cleaning step.

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# In information retrieval, **TF-IDF**, or **term frequency–inverse document frequency**, is a numerical statistic that reflects how relevant a word is to a document in a collection or corpus. The TF-IDF value increases proportionally to the number of times a word appears in the document and is offset by the frequency of the word in the corpus, which helps to adjust for the fact that some words appear more frequently in general. (source:wiki)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf = TfidfTransformer()
X = tfidf.fit_transform(X).toarray()

# %% [markdown]
# ## train-test-split

# %% [markdown]
# We will split X and y into train and test sets.For this we will use the train-test-split class from scitkit-learn, with a training size of 80 % and a test size of 20 %. You can also have an additional dev set, but for now let's keep it simple.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0) # shuffle is by default true

# %% [markdown]
# # Support Vector Machines

# %% [markdown]
# Support Vector Machines **(SVMs)** are supervised machine learning models used for classification, regression and outlier detection.
#
# The advantages of support vector machines are:
#
# * Effective in high dimensional spaces.
# * Still effective in cases where number of dimensions is greater than the number of samples.
# * Uses a subset of training points in the decision function (called support vectors), so it is also memory efficient.
# * Versatile: different Kernel functions can be specified for the decision function. Common kernels are provided, but it is also possible to specify custom kernels.
#
# The disadvantages of support vector machines include:
#
# * If the number of features is much greater than the number of samples, avoid over-fitting in choosing Kernel functions and regularization term is crucial.
# * SVMs do not directly provide probability estimates, these are calculated using an expensive five-fold cross-validation (see Scores and probabilities, below).
#
# In addition to performing linear classification, SVMs can efficiently perform non-linear classifications using the **kernel trick**, elevating and mapping the inputs into high-dimensional feature spaces.
#
# There are many paramters, some of which are very sensitive. Some of the most important SVM parameters:
#
# * **C :** float, optional (default=1.0). Penalty parameter C of the error term.
# * **kernel :** string, optional (default=’rbf’). Specifies the kernel type to be used in the algorithm.
#     It must be one of ‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’ or a callable. If none is given, ‘rbf’ will be used. If a callable is given it is used to pre-compute the kernel matrix from data matrices; that matrix should be an array of shape (n_samples, n_samples).
# * **gamma :** float, optional (default=’auto’). Kernel coefficient for ‘rbf’, ‘poly’ and ‘sigmoid’. If gamma is ‘auto’ then 1/n_features will be used instead.
# * **class_weight :** {dict, ‘balanced’}, optional. Set the parameter C of class i to class_weight[i]*C for SVC.
#     If not given, all classes are supposed to have weight one. The “balanced” mode uses the values of y to automatically adjust weights inversely proportional to class frequencies in the input data as n_samples / (n_classes * np.bincount(y))
# * **decision_function_shape :** ‘ovo’, ‘ovr’, default=’ovr’. Whether to return a one-vs-rest (‘ovr’) decision function of shape (n_samples, n_classes) as all other classifiers, or the original one-vs-one (‘ovo’) decision function of libsvm which has shape (n_samples, n_classes * (n_classes - 1) / 2).
# * **random_state :** int, RandomState instance or None, optional (default=None). The seed of the pseudo random number generator to use when shuffling the data. If int, random_state is the seed used by the random number generator; If RandomState instance, random_state is the random number generator; If None, the random number generator is the RandomState instance used by np.random.
#
# (source: scikit-learn)

# %% [markdown]
# # SVM

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ## Predicting the result

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# ## Let's get the F1 score.
# F1 = 2 * (precision * recall) / (precision + recall)

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred)
# Out:
# 0.7186518869737937

# %% [markdown]
# The results are not impressive, especially when comparing to the Kaggle leaderboard, with top results around 0.79. But it's a good start and it gives us a baseline to further improve upon.

# %% [markdown]
# # TODO

# %% [markdown]
# * Handle imbalanced classes
# * Cleaning should be done more thoroughly
# * GridSearch for finding the optimal parameters

# %% [markdown]
# ## Grid search and training the classifier

# %% [markdown]
# Let's use **GridSearchCV** to make sure to **identifiy the best for values for the paramters C and gamma, as well as choose between the sigmoid and the rbf kernel.** We then train our SVM classifier, print the best estimators and finally make the predictions on the test data. All supervised estimators in scikit-learn implement a **fit(X, y)** method to fit the model and a **predict(X)** method that, given unlabeled observations X, returns the predicted labels y.

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# Create a dictionary with a range of parameter values for C, gamma and the kernel
parameters = {'C': [0.01, 0.1, 1], # default: 1.0
          'gamma': [0.001, 0.01, 0.1], # default: auto
          'kernel':['sigmoid','rbf'] }

svc = SVC()
clf = GridSearchCV(svc, parameters)

# Fit the data with the best possible parameters
clf.fit(X_train, y_train)

#Print the best estimator with its parameters
print(clf.best_estimators)
